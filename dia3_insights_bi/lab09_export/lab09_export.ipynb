# %% [markdown]
# LAB 9

# %%
con.execute("CREATE OR REPLACE TABLE gold_fraud_risk AS SELECT * FROM read_parquet('bigdata/gold/fraud_risk.parquet')")

con.execute("COPY gold_fraud_risk TO 'fraud_risk_export.csv' (HEADER, DELIMITER ',')")
print(pd.read_csv('fraud_risk_export.csv'))
# Out:
#      segment  total_transacoes   valor_total  ticket_medio  qtd_fraudes  \
# 0    Premium             61156  1.123504e+07        183.71        473.0
# 1   Standard             29689  5.479400e+06        184.56        655.0
# 2  High-Risk              9155  1.664640e+06        181.83        705.0
#
#    taxa_fraude_pct  valor_em_risco
# 0             0.77    81308.437996
# 1             2.21   106828.419109
# 2             7.70   126451.069108
